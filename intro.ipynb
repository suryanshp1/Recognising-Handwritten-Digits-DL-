# %%
import tensorflow
import seaborn as sns

# %%
from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(n_samples=10000, centers=2, random_state=42)

# %%
sns.scatterplot(X[:, 0], X[:, 1], hue=y)
# Out:
# C:\Users\Suraj\anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
y_mod = y.reshape(-1, 1)

# %%
y_mod.shape
# Out:
# (10000, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

dl = Dense(units=1, activation="sigmoid", input_shape=(2,))

model.add(dl)

model.summary()

# %%
model.weights
# Out:
# [<tf.Variable 'dense_1/kernel:0' shape=(2, 1) dtype=float32, numpy=
#  array([[-1.0406849 ],
#         [ 0.26278389]], dtype=float32)>,
#  <tf.Variable 'dense_1/bias:0' shape=(1,) dtype=float32, numpy=array([0.], dtype=float32)>]

# %%
from sklearn.model_selection import train_test_split

# %%
>>> X_train, X_test, y_train, y_test = train_test_split(
...     X, y_mod, test_size=0.33, random_state=42)

# %%
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %%
model.fit(X_train, y_train, epochs=10, batch_size=1000)
# Out:
# Epoch 1/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 2/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 3/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 4/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 5/10
# 7/7 [==============================] - 0s 1000us/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 6/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 7/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 8/10
# 7/7 [==============================] - 0s 862us/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 9/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 10/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0049 - accuracy: 1.0000

# %%
model.evaluate(X_test, y_test, verbose=0)
# Out:
# [0.004479523282498121, 1.0]

# %%
y_train.shape
# Out:
# (6700, 1)
